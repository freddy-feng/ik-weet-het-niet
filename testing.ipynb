# %%
# %run deck_class.py

random.seed(123)

# %% [markdown]
# # Testing - valid values + edge cases

# %%
test = Deck()
for session in range(10):
    for score in range(6):
        for key in test.df['key']:
            #print(f'session{session}; score{score}; key{key}')
            test.update_df(session, key, score)

# Result
test.df
# Out:
#         key                                    link  n_visit  \
# 0    Hearts    https://www.woorden.org/woord/Hearts       60
# 1  Diamonds  https://www.woorden.org/woord/Diamonds       60
# 2     Clubs     https://www.woorden.org/woord/Clubs       60
# 3    Spades    https://www.woorden.org/woord/Spades       60
#
#                   last_visit  study_interval  is_current  is_retired box_id  \
# 0 2023-03-16 21:02:34.226775               0       False       False   6815
# 1 2023-03-16 21:02:34.228770               0       False       False   2471
# 2 2023-03-16 21:02:34.230765               0       False       False   7926
# 3 2023-03-16 21:02:34.232759               0       False       False   4693
#
#    easiness                                    n_scores
# 0       2.5  {0: 10, 1: 10, 2: 10, 3: 10, 4: 10, 5: 10}
# 1       2.5  {0: 10, 1: 10, 2: 10, 3: 10, 4: 10, 5: 10}
# 2       2.5  {0: 10, 1: 10, 2: 10, 3: 10, 4: 10, 5: 10}
# ...
